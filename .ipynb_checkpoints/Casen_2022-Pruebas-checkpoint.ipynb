# %%
#pip install pandas pyreadstat openpyxl

# %%
import pandas as  pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %%
#Variables a estudiar
'region','area','nse','edad','sexo','e6a','o15',
'o22','o26a', 'y1','y7', 'y8','y12a', 'y15b',
'y15c', 'y16a', 'y16b', 'y28_2b1', 'y28_3b', 'y28_4b', 'y28_1c2monto',
'y28_2c1', 'y28_2c2', 'y28_2c', 'y28_3c', 'y28_4c','y28_2i2', 's13', 
's15','s26b_3', 's26b_6', 'v1', 'v9', 'v12mt', 'v17'
# Out:
# ('s15', 's26b_3', 's26b_6', 'v1', 'v9', 'v12mt', 'v17')

# %%
df = pd.read_stata('Base de datos Casen 2022 STATA.dta', convert_categoricals=False)
df.head()
# Out:
#    id_vivienda      folio  id_persona  region  area  cod_upm  nse  estrato  \
# 0      1000901  100090101           1      16     2    10009    4  1630324
# 1      1000901  100090101           2      16     2    10009    4  1630324
# 2      1000901  100090101           3      16     2    10009    4  1630324
# 3      1000902  100090201           1      16     2    10009    4  1630324
# 4      1000902  100090201           2      16     2    10009    4  1630324
#
#    hogar  expr  ...  men18c  may60c  tipohogar tot_hog  ind_hacina  indsan  \
# 0      1    43  ...       0       1          3       1           1       1
# 1      1    43  ...       0       1          3       1           1       1
# 2      1    44  ...       0       1          3       1           1       1
# 3      1    51  ...       1       1          5       1           1       2
# 4      1    51  ...       1       1          5       1           1       2
#
#    ten_viv  ten_viv_f  allega_ext  allega_int
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202231 entries, 0 to 202230
# Columns: 917 entries, id_vivienda to allega_int
# dtypes: datetime64[ns](1), float32(16), float64(590), int16(9), int32(116), int8(152), object(33)
# memory usage: 1.1+ GB

# %%
#Generar archivo excel con las variables a estudiar 

# Lista de variables a cargar
variables_a_cargar = ['region','area','nse','edad','sexo',
'e6a','o15','o19',
'o22','rama1_sub','o26a','o31', 'o32','o32_esp',
'y1','y7', 'y8','y12a_preg','y12a','y15b_preg', 'y15b', 
'y15c_preg', 'y15c','y16a_preg', 'y16a', 'y16b_preg', 'y16b',
'y18d_preg', 'y28_1b', 'y28_1c', 'y28_2b1',
'y28_2b2', 'y28_3b', 'y28_4b', 'y28_1c1', 'y28_1c2', 
'y28_1c2monto', 'y28_2c1', 'y28_2c2', 'y28_2c', 'y28_3c', 
'y28_4c', 'y28_2f', 'y28_3f', 'y28_4f', 'y28_2g2', 'y28_1i1', 
'y28_2i1', 'y28_2i2', 'y28_3j', 'y28_4j', 's2', 's13', 
's13_fonasa', 's15', 's26b_3', 's26b_6', 'v1', 'v9', 'v12mt', 'v16', 'v17'
]

# Cargar las variables desde el archivo Stata
#df = pd.read_stata('Base de datos Casen 2022 STATA.dta', columns=variables_a_cargar)

# Guardar el DataFrame resultante en un archivo Excel llamado Casen_2022
#df.to_excel('casen_2022.xlsx', index=False)

# %%
#Conocer el tipo de dato de cada variable a estudiar

#Generar lista con las variables a revisar en el código siguiente:
variables_interesantes = [
'region','area','nse','edad','sexo','e6a','o15',
'o22','o26a', 'y1','y7', 'y8','y12a', 'y15b',
'y15c', 'y16a', 'y16b', 'y28_2b1', 'y28_3b', 'y28_4b', 'y28_1c2monto',
'y28_2c1', 'y28_2c2', 'y28_2c', 'y28_3c', 'y28_4c','y28_2i2', 's13', 
's15','s26b_3', 's26b_6', 'v1', 'v9', 'v12mt', 'v17']

# Obtener los tipos de datos de las variables seleccionadas
tipos_de_datos = df[variables_interesantes].dtypes

# Visualizar las filas deseadas
print(tipos_de_datos.head(40))
# Out:
# region             int8
# area               int8
# nse                int8
# edad              int16
# sexo               int8
# e6a                int8
# o15             float64
# o22             float64
# o26a            float64
# y1              float64
# y7              float64
# y8              float64
# y12a            float64
# y15b            float64
# y15c            float64
# y16a            float64
# y16b            float64
# y28_2b1         float64
# y28_3b          float64
# y28_4b          float64
# y28_1c2monto    float32
# y28_2c1         float64
# y28_2c2         float64
# y28_2c          float64
# y28_3c          float64
# y28_4c          float64
# y28_2i2         float64
# s13                int8
# s15             float64
# s26b_3          float64
# s26b_6          float64
# v1                 int8
# v9                 int8
# v12mt           float64
# v17             float64
# dtype: object

# %%
# Columna a estudiar
frecuencia_region = df['region'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_region)
# Out:
# region
# 13    38674
# 5     20552
# 8     19914
# 6     13864
# 7     13739
# 9     13577
# 10    10707
# 14    10603
# 2      9029
# 3      9011
# 16     8706
# 1      8691
# 4      8236
# 15     8152
# 12     5029
# 11     3747
# Name: count, dtype: int64

# %%
# Columna a estudiar
frecuencia_nse = df['nse'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_nse)
# Out:
# nse
# 4    56021
# 2    50219
# 1    40915
# 3    19924
# 6    19078
# 7    15813
# 5      261
# Name: count, dtype: int64

# %%
#y28_2c. Monto Jubilación o Pensión de Vejez

# Columna a estudiar
frecuencia_y28_2c = df['y28_2c'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_y28_2c)
# Out:
# y28_2c
#  200000.0     355
#  180000.0     322
# -88.0         320
#  193000.0     319
#  300000.0     291
#              ...
#  239000.0       1
#  2000090.0      1
#  475000.0       1
#  38000.0        1
#  105840.0       1
# Name: count, Length: 615, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#¿En su empleo principal, pertenece a Sindicato?


# Columna a estudiar
frecuencia_o26a = df['o26a'].value_counts()

# Mostrar la frecuencia de la variable 
print(frecuencia_o26a)
# Out:
# o26a
#  2.0     70728
#  1.0      9570
# -88.0     1182
# Name: count, dtype: int64

# %%
#Realizar estadistica descriptiva a los datos

columnas_interesantes = ['region','area','nse','edad','sexo','e6a','o15',
'o22','o26a', 'y1','y7', 'y8','y12a', 'y15b',
'y15c', 'y16a', 'y16b', 'y28_2b1', 'y28_3b', 'y28_4b', 'y28_1c2monto',
'y28_2c1', 'y28_2c2', 'y28_2c', 'y28_3c', 'y28_4c','y28_2i2', 's13', 
's15','s26b_3', 's26b_6', 'v1', 'v9', 'v12mt', 'v17'
]

resumen_columnas = df[columnas_interesantes].describe().round(0)
resumen_columnas
# Out:
#          region      area       nse      edad      sexo       e6a      o15  \
# count  202231.0  202231.0  202231.0  202231.0  202231.0  202231.0  85710.0
# mean        9.0       1.0       3.0      39.0       2.0       9.0      4.0
# std         4.0       0.0       2.0      23.0       0.0       3.0      2.0
# min         1.0       1.0       1.0       0.0       1.0       1.0      1.0
# 25%         5.0       1.0       2.0      20.0       1.0       7.0      2.0
# 50%         8.0       1.0       3.0      38.0       2.0       9.0      5.0
# 75%        13.0       1.0       4.0      58.0       2.0      11.0      5.0
# max        16.0       2.0       7.0     120.0       2.0      15.0      9.0
#
#            o22     o26a          y1  ...  y28_4c   y28_2i2       s13      s15  \
# count  61363.0  81480.0     61363.0  ...  3359.0      17.0  202231.0  86114.0
# mean       1.0      1.0    643252.0  ...    -8.0   95431.0       0.0      1.0
# ...

# %%
# Nombre de la columna que quieres visualizar en el histograma
data = df['y28_2c']

# Crear el histograma
plt.hist(data, bins=80, color='blue', edgecolor='black')

# Personalizar el gráfico
plt.title('Casen 2022 y28_2b1')
plt.xlabel('Valor de y28_2b1')
plt.ylabel('Frecuencia')

# Mostrar el histograma
plt.show()

# %%
# Nombre de la columna que quieres visualizar en el histograma
data = df['nse']

# Crear el histograma
plt.hist(data, bins=8, color='blue', edgecolor='black')

# Personalizar el gráfico
plt.title('Histograma de y28_2b1')
plt.xlabel('Valor de y28_2b1')
plt.ylabel('Frecuencia')

# Mostrar el histograma
plt.show()

# %%
# Nombre de la columna que quieres visualizar en el histograma
data = df['v9']

# Crear el histograma
plt.hist(data, bins=11, color='blue', edgecolor='black')

# Personalizar el gráfico
plt.title('Histograma de y28_2b1')
plt.xlabel('Valor de y28_2b1')
plt.ylabel('Frecuencia')

# Mostrar el histograma
plt.show()

# %%
# Nombre de la columna que quieres visualizar en el histograma
data = df['v1']

# Crear el histograma
plt.hist(data, bins=11, color='blue', edgecolor='black')

# Personalizar el gráfico
plt.title('Histograma de y28_2b1')
plt.xlabel('Valor de y28_2b1')
plt.ylabel('Frecuencia')

# Mostrar el histograma
plt.show()

# %%
# Selecciona las columnas de interés
columnas_interes = df[['region','area','nse','edad','sexo',
                       'e6a','o15','o22', 'o26a','o31',
                       'o32', 'y1','y7', 'y8', 'y12a','y15b',
                       'y15c','y16a', 'y16b', 'y28_2c'
]]

# Configura el estilo de Seaborn (opcional)
sns.set(style="whitegrid")

# Crea un mapa de calor a partir de las columnas seleccionadas
plt.figure(figsize=(14, 10))  # Tamaño de la figura
sns.heatmap(columnas_interes.corr(), annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")  # Calcula la correlación 
                                                                                   # y muestra los valores

plt.title("Mapa de calor")  # Título del gráfico
plt.show()

# %%
# Selecciona las columnas de interés
columnas_interes = df[['region','area','nse','edad','sexo',
                       'y1', 'e6a',
                       'y28_2b1', 'y28_3b', 'y28_4b',
                       'y28_2c1', 'y28_2c2','y28_2c', 'y28_3c', 'y28_4c',
                       'y28_2i2', 's13','s15', 's26b_3', 's26b_6'
                       ]]

# Configura el estilo de Seaborn (opcional)
sns.set(style="whitegrid")

# Crea un mapa de calor a partir de las columnas seleccionadas
plt.figure(figsize=(14, 10))  # Tamaño de la figura
sns.heatmap(columnas_interes.corr(), annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")  # Calcula la correlación 
                                                                                   # y muestra los valores

plt.title("Mapa de calor")  # Título del gráfico
plt.show()

# %%
# Selecciona las columnas de interés
columnas_interes = df[['y28_2b1', 'y28_3b', 'y28_4b',
                       'y28_2c1', 'y28_2c2','y28_2c', 'y28_3c', 'y28_4c',
                       'e6a','y28_2i2', 's13', 
                       's15', 's26b_3', 's26b_6', 'v1', 
                       'v9', 'v12mt', 'v17', 'y1'                         
                       ]]

# Configura el estilo de Seaborn (opcional)
sns.set(style="whitegrid")

# Crea un mapa de calor a partir de las columnas seleccionadas
plt.figure(figsize=(14, 10))  # Tamaño de la figura
sns.heatmap(columnas_interes.corr(), annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")  # Calcula la correlación 
                                                                                   # y muestra los valores

plt.title("Mapa de calor")  # Título del gráfico
plt.show()

# %%
# Selecciona las columnas de interés
columnas_interes = df[['area','sexo','edad','e6a','y1','y7',
                       'y12a', 'y15b', 'y15c', 'y16a', 'y16b', 'y28_1c', 
                       'y28_2b1', 'y28_4b', 'y28_2c'                      
]]

# Configura el estilo de Seaborn (opcional)
sns.set(style="whitegrid")

# Crea un mapa de calor a partir de las columnas seleccionadas
plt.figure(figsize=(14, 10))  # Tamaño de la figura
sns.heatmap(columnas_interes.corr(), annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")  # Calcula la correlación 
                                                                                   # y muestra los valores

plt.title("Mapa de calor")  # Título del gráfico
plt.show()

# %%
# Selecciona las columnas de interés
columnas_interes = df[['area','sexo','e6a','y1','y7',
                       'y28_2i2', 's13', 's26b_3', 's26b_6', 'v12mt', 'v17', 'y28_2c'
]]

# Configura el estilo de Seaborn (opcional)
sns.set(style="whitegrid")

# Crea un mapa de calor a partir de las columnas seleccionadas
plt.figure(figsize=(14, 10))  # Tamaño de la figura
sns.heatmap(columnas_interes.corr(), annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")  # Calcula la correlación 
                                                                                   # y muestra los valores

plt.title("Mapa de calor")  # Título del gráfico
plt.show()

# %%
# Supongamos que tienes un DataFrame llamado 'data' con las columnas 'region', 'ytrabajocor', 'esc' y 'desercion'

# Agrupar por 'region' y aplicar funciones de agregación
df_region = df.groupby('region').agg({'y1': 'mean', 'e6a': 'mean'}).reset_index()

# Ahora contiene los resultados agregados por región
df_region.head(40)
# Out:
#     region             y1       e6a
# 0        1  675081.845382  8.869980
# 1        2  734300.618713  9.029571
# 2        3  681739.174944  8.705915
# 3        4  623465.234842  8.786790
# 4        5  588315.815233  9.050360
# 5        6  580964.094294  8.594922
# 6        7  489104.425266  8.511245
# 7        8  575979.589810  8.841920
# 8        9  505048.166017  8.591736
# 9       10  567165.692138  8.472962
# 10      11  774360.626841  8.784895
# 11      12  746749.609756  9.162060
# 12      13  816262.491329  9.364948
# 13      14  553767.148027  8.710271
# 14      15  610200.548211  9.065505
# 15      16  498044.687583  8.427751

# %%
# Suponiendo que casen_2022 es tu DataFrame
sns.regplot(data=df_region, y='y1', x='e6a', ci=95, line_kws={'color': 'magenta'}) 
# El argumento ci controla el intervalo de confianza
plt.ylabel('y1')
plt.xlabel('escolaridad')
plt.title('Scatter Plot con Línea de Regresión y Intervalo de Confianza')
plt.show()

# %%
# Suponiendo que casen_2022_region es tu DataFrame
sns.set(style='whitegrid')  # Configuración del estilo del gráfico

# Agregar una columna de constante al DataFrame
df_region['constante'] = 1

# Crear el gráfico de dispersión con la línea de regresión
sns.regplot(data=df_region, y='y1', x='e6a', ci=95, line_kws={'color': 'magenta'}, scatter_kws={'color': 'blue'})  # El argumento ci controla el intervalo de confianza

# Ajustar el modelo de regresión lineal
y = df_region['y1']
X = df_region[['e6a', 'constante']]  # 'constante' es la columna que agregamos para el término constante
modelo = sm.OLS(y, X).fit()

# Calcular las predicciones ('ytrabajocor_pred') a partir del modelo
df_region['y1_pred'] = modelo.predict(X)

# Agregar líneas que conecten cada punto a la línea de regresión
for i in range(len(df_region)):
    x_point = df_region['e6a'][i]
    y_point = df_region['y1'][i]
    y_pred = df_region['y1_pred'][i]  # Usamos las predicciones del modelo
    
    # Línea que conecta el punto a la línea de regresión
    plt.plot([x_point, x_point], [y_point, y_pred], linestyle='--', color='gray')

plt.ylabel('Ingresos')
plt.xlabel('Escolaridad')
plt.title('Lineas de regresión y residuos')
plt.show()

# %%
# Supongamos que 'casen_2022' contiene las columnas 'ytrabajocor' (variable dependiente) y 'esc' (variable independiente),
# y que puedes tener valores NaN en tus datos.

# Eliminar filas con valores NaN
df_clean = df_region.dropna(subset=['y1', 'e6a'])

# Agregar una columna de constantes para el término constante en el modelo
df_clean['constante'] = 1

# Definir las variables dependiente e independiente
y = df_clean['y1']
X = df_clean[['constante', 'e6a']]  # Usar 'constante' como término constante

# Ajustar el modelo de regresión lineal
modelo = sm.OLS(y, X).fit()

# Imprimir un resumen del modelo
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     y1   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.524
# Method:                 Least Squares   F-statistic:                     17.50
# Date:                Sat, 02 Dec 2023   Prob (F-statistic):           0.000920
# Time:                        16:03:28   Log-Likelihood:                -200.15
# No. Observations:                  16   AIC:                             404.3
# Df Residuals:                      14   BIC:                             405.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# constante  -1.867e+06   5.96e+05     -3.131      0.007   -3.15e+06   -5.88e+05
# ...
